# %% [markdown]
# # **Programación IV**
# ## *Archivo 1, Clase 6*
#
# Grupo: 1
#
# Profesor: Andrés Felipe Ramírez Correa
#
# Nombre: Carlos Eduardo Grisales Restrepo
#
# Codigo: 1055750849
#
# **Tema: Herencia Múltiple y Modularidad**
